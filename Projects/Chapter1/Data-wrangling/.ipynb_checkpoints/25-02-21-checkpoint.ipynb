# %%
ls
# Out:
# 25-02-21.ipynb                         fastq-sommers2020/
# Sommers2020/                           fastq-sommers2020.tar.gz
# add-categorical-numeric-to-metadata.R  fastq-sommers2020copy/

# %%
! ls
# Out:
# 25-02-21.ipynb                        fastq-sommers2020
# Sommers2020                           fastq-sommers2020.tar.gz
# add-categorical-numeric-to-metadata.R fastq-sommers2020copy
